# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
# Define the unconditional diffusion model
class UnconditionalDiffusionModel(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(UnconditionalDiffusionModel, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, input_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# Define the negative log-likelihood loss function
def nll_loss(x, y):
    return torch.mean(torch.sum((x - y) ** 2, dim=1))

# Define the perceptual loss function
def perceptual_loss(x, y):
    return torch.mean(torch.abs(x - y))

# %%
# Load the MNIST dataset
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)

# %%
# Initialize the unconditional diffusion model
unconditional_model = UnconditionalDiffusionModel(input_size=784, hidden_size=256)

# Define the optimizer for the unconditional model
unconditional_optimizer = optim.Adam(unconditional_model.parameters(), lr=0.001)

# Train the unconditional diffusion model
for epoch in range(10):
    for i, (images, _) in enumerate(train_loader):
        # Flatten the images
        images = images.view(images.size(0), -1)

        # Forward pass
        outputs = unconditional_model(images)

        # Compute the loss
        loss = nll_loss(outputs, images)

        # Backward and optimize
        unconditional_optimizer.zero_grad()
        loss.backward()
        unconditional_optimizer.step()

        # Print the loss
        if (i+1) % 100 == 0:
            print('Unconditional Model - Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch+1, 10, i+1, len(train_loader), loss.item()))
# Out:
# Unconditional Model - Epoch [1/10], Step [100/938], Loss: 16.1924
# Unconditional Model - Epoch [1/10], Step [200/938], Loss: 9.4988
# Unconditional Model - Epoch [1/10], Step [300/938], Loss: 7.3711
# Unconditional Model - Epoch [1/10], Step [400/938], Loss: 6.0698
# Unconditional Model - Epoch [1/10], Step [500/938], Loss: 5.4503
# Unconditional Model - Epoch [1/10], Step [600/938], Loss: 4.6286
# Unconditional Model - Epoch [1/10], Step [700/938], Loss: 4.1888
# Unconditional Model - Epoch [1/10], Step [800/938], Loss: 4.0051
# Unconditional Model - Epoch [1/10], Step [900/938], Loss: 3.6695
# Unconditional Model - Epoch [2/10], Step [100/938], Loss: 3.3171
# Unconditional Model - Epoch [2/10], Step [200/938], Loss: 3.3141
# Unconditional Model - Epoch [2/10], Step [300/938], Loss: 2.8452
# Unconditional Model - Epoch [2/10], Step [400/938], Loss: 2.8674
# Unconditional Model - Epoch [2/10], Step [500/938], Loss: 2.9525
# Unconditional Model - Epoch [2/10], Step [600/938], Loss: 2.8319
# Unconditional Model - Epoch [2/10], Step [700/938], Loss: 2.5346
# Unconditional Model - Epoch [2/10], Step [800/938], Loss: 2.6980
# Unconditional Model - Epoch [2/10], Step [900/938], Loss: 2.8278
# Unconditional Model - Epoch [3/10], Step [100/938], Loss: 2.4057
# Unconditional Model - Epoch [3/10], Step [200/938], Loss: 2.6627
# Unconditional Model - Epoch [3/10], Step [300/938], Loss: 2.4932
# Unconditional Model - Epoch [3/10], Step [400/938], Loss: 2.3496
# Unconditional Model - Epoch [3/10], Step [500/938], Loss: 2.4307
# Unconditional Model - Epoch [3/10], Step [600/938], Loss: 2.5190
# Unconditional Model - Epoch [3/10], Step [700/938], Loss: 2.3304
# Unconditional Model - Epoch [3/10], Step [800/938], Loss: 2.5797
# Unconditional Model - Epoch [3/10], Step [900/938], Loss: 2.3418
# Unconditional Model - Epoch [4/10], Step [100/938], Loss: 2.2674
# Unconditional Model - Epoch [4/10], Step [200/938], Loss: 2.1852
# Unconditional Model - Epoch [4/10], Step [300/938], Loss: 2.1420
# Unconditional Model - Epoch [4/10], Step [400/938], Loss: 2.1849
# Unconditional Model - Epoch [4/10], Step [500/938], Loss: 2.3398
# Unconditional Model - Epoch [4/10], Step [600/938], Loss: 2.2676
# Unconditional Model - Epoch [4/10], Step [700/938], Loss: 2.1970
# Unconditional Model - Epoch [4/10], Step [800/938], Loss: 1.9731
# Unconditional Model - Epoch [4/10], Step [900/938], Loss: 2.0974
# Unconditional Model - Epoch [5/10], Step [100/938], Loss: 2.2278
# Unconditional Model - Epoch [5/10], Step [200/938], Loss: 2.1232
# Unconditional Model - Epoch [5/10], Step [300/938], Loss: 2.4343
# Unconditional Model - Epoch [5/10], Step [400/938], Loss: 2.2479
# Unconditional Model - Epoch [5/10], Step [500/938], Loss: 2.1130
# Unconditional Model - Epoch [5/10], Step [600/938], Loss: 2.1718
# Unconditional Model - Epoch [5/10], Step [700/938], Loss: 2.1726
# Unconditional Model - Epoch [5/10], Step [800/938], Loss: 2.2192
# Unconditional Model - Epoch [5/10], Step [900/938], Loss: 2.2609
# Unconditional Model - Epoch [6/10], Step [100/938], Loss: 2.0554
# Unconditional Model - Epoch [6/10], Step [200/938], Loss: 2.1541
# Unconditional Model - Epoch [6/10], Step [300/938], Loss: 1.8590
# Unconditional Model - Epoch [6/10], Step [400/938], Loss: 1.9574
# Unconditional Model - Epoch [6/10], Step [500/938], Loss: 2.2364
# Unconditional Model - Epoch [6/10], Step [600/938], Loss: 2.0349
# Unconditional Model - Epoch [6/10], Step [700/938], Loss: 1.9206
# Unconditional Model - Epoch [6/10], Step [800/938], Loss: 2.2290
# Unconditional Model - Epoch [6/10], Step [900/938], Loss: 1.9210
# Unconditional Model - Epoch [7/10], Step [100/938], Loss: 2.1160
# Unconditional Model - Epoch [7/10], Step [200/938], Loss: 2.0768
# Unconditional Model - Epoch [7/10], Step [300/938], Loss: 2.0731
# Unconditional Model - Epoch [7/10], Step [400/938], Loss: 2.1240
# Unconditional Model - Epoch [7/10], Step [500/938], Loss: 2.1756
# Unconditional Model - Epoch [7/10], Step [600/938], Loss: 2.2417
# Unconditional Model - Epoch [7/10], Step [700/938], Loss: 2.1730
# Unconditional Model - Epoch [7/10], Step [800/938], Loss: 2.0165
# Unconditional Model - Epoch [7/10], Step [900/938], Loss: 2.3005
# Unconditional Model - Epoch [8/10], Step [100/938], Loss: 2.1927
# Unconditional Model - Epoch [8/10], Step [200/938], Loss: 2.0765
# Unconditional Model - Epoch [8/10], Step [300/938], Loss: 2.1843
# Unconditional Model - Epoch [8/10], Step [400/938], Loss: 2.2635
# Unconditional Model - Epoch [8/10], Step [500/938], Loss: 1.8546
# Unconditional Model - Epoch [8/10], Step [600/938], Loss: 1.9038
# Unconditional Model - Epoch [8/10], Step [700/938], Loss: 2.1672
# Unconditional Model - Epoch [8/10], Step [800/938], Loss: 2.2626
# Unconditional Model - Epoch [8/10], Step [900/938], Loss: 2.3312
# Unconditional Model - Epoch [9/10], Step [100/938], Loss: 2.0261
# Unconditional Model - Epoch [9/10], Step [200/938], Loss: 1.9285
# Unconditional Model - Epoch [9/10], Step [300/938], Loss: 2.0200
# Unconditional Model - Epoch [9/10], Step [400/938], Loss: 2.1933
# Unconditional Model - Epoch [9/10], Step [500/938], Loss: 1.8664
# Unconditional Model - Epoch [9/10], Step [600/938], Loss: 2.2513
# Unconditional Model - Epoch [9/10], Step [700/938], Loss: 2.3753
# Unconditional Model - Epoch [9/10], Step [800/938], Loss: 2.1922
# Unconditional Model - Epoch [9/10], Step [900/938], Loss: 2.1937
# Unconditional Model - Epoch [10/10], Step [100/938], Loss: 1.9866
# Unconditional Model - Epoch [10/10], Step [200/938], Loss: 1.9740
# Unconditional Model - Epoch [10/10], Step [300/938], Loss: 1.9780
# Unconditional Model - Epoch [10/10], Step [400/938], Loss: 2.0615
# Unconditional Model - Epoch [10/10], Step [500/938], Loss: 2.1961
# Unconditional Model - Epoch [10/10], Step [600/938], Loss: 1.9569
# Unconditional Model - Epoch [10/10], Step [700/938], Loss: 1.7809
# Unconditional Model - Epoch [10/10], Step [800/938], Loss: 1.9151
# Unconditional Model - Epoch [10/10], Step [900/938], Loss: 1.9648

# %%
# Evaluate the unconditional diffusion model using negative log-likelihood and perceptual metrics
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transforms.ToTensor())
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# Evaluate the unconditional diffusion model using negative log-likelihood and perceptual metrics
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transforms.ToTensor())
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)

nll_loss_total = 0
perceptual_loss_total = 0
with torch.no_grad():
    for images, _ in test_loader:
        # Flatten the images
        images = images.view(images.size(0), -1)

        # Forward pass
        outputs = unconditional_model(images)

        # Compute the negative log-likelihood loss
        nll_loss_total += nll_loss(outputs, images).item()

        # Compute the perceptual loss
        perceptual_loss_total += perceptual_loss(outputs, images).item()

        # Plot the original and reconstructed images
        fig, axs = plt.subplots(1, 2)
        axs[0].imshow(images[0].view(28, 28), cmap='gray')
        axs[0].set_title('Original')
        axs[1].imshow(outputs[0].view(28, 28), cmap='gray')
        axs[1].set_title('Reconstructed')
        plt.show()

nll_loss_avg = nll_loss_total / len(test_loader)
perceptual_loss_avg = perceptual_loss_total / len(test_loader)

print('Unconditional Model - Negative Log-Likelihood Loss: {:.4f}'.format(nll_loss_avg))
print('Unconditional Model - Perceptual Loss: {:.4f}'.format(perceptual_loss_avg))
# Out:
# Unconditional Model - Negative Log-Likelihood Loss: 2.1193
# Unconditional Model - Perceptual Loss: 0.0302
