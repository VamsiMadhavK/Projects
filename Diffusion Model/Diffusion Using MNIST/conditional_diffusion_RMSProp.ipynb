# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
# Out:
# C:\Users\vamsi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: 'Could not find module 'C:\Users\vamsi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\image.pyd' (or one of its dependencies). Try using the full path with constructor syntax.'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
# Define the conditional diffusion model
class ConditionalDiffusionModel(nn.Module):
    def __init__(self, input_size, hidden_size, condition_size):
        super(ConditionalDiffusionModel, self).__init__()
        self.fc1 = nn.Linear(input_size + condition_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, input_size)

    def forward(self, x, c):
        x = torch.cat([x, c], dim=1)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# Define the negative log-likelihood loss function
def nll_loss(x, y):
    return torch.mean(torch.sum((x - y) ** 2, dim=1))

# Define the perceptual loss function
def perceptual_loss(x, y):
    return torch.mean(torch.abs(x - y))

# %%
# Load the MNIST dataset
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)

# %%
# Initialize the conditional diffusion model
conditional_model = ConditionalDiffusionModel(input_size=784, hidden_size=256, condition_size=10)

# Define the optimizer for the conditional model
conditional_optimizer = optim.RMSprop(conditional_model.parameters(), lr=0.001)

# Train the conditional diffusion model
for epoch in range(10):
    for i, (images, labels) in enumerate(train_loader):
        # Flatten the images
        images = images.view(images.size(0), -1)

        # One-hot encode the labels
        labels_onehot = torch.zeros(images.size(0), 10)
        labels_onehot.scatter_(1, labels.view(-1, 1), 1)

        # Forward pass
        outputs = conditional_model(images, labels_onehot)

        # Compute the loss
        loss = nll_loss(outputs, images)

        # Backward and optimize
        conditional_optimizer.zero_grad()
        loss.backward()
        conditional_optimizer.step()

        # Print the loss
        if (i+1) % 100 == 0:
            print('Conditional Model - Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch+1, 10, i+1, len(train_loader), loss.item()))
# Out:
# Conditional Model - Epoch [1/10], Step [100/938], Loss: 25.2241
# Conditional Model - Epoch [1/10], Step [200/938], Loss: 17.8891
# Conditional Model - Epoch [1/10], Step [300/938], Loss: 16.4738
# Conditional Model - Epoch [1/10], Step [400/938], Loss: 13.5081
# Conditional Model - Epoch [1/10], Step [500/938], Loss: 14.7752
# Conditional Model - Epoch [1/10], Step [600/938], Loss: 11.2318
# Conditional Model - Epoch [1/10], Step [700/938], Loss: 9.3799
# Conditional Model - Epoch [1/10], Step [800/938], Loss: 8.6293
# Conditional Model - Epoch [1/10], Step [900/938], Loss: 13.8460
# Conditional Model - Epoch [2/10], Step [100/938], Loss: 8.9032
# Conditional Model - Epoch [2/10], Step [200/938], Loss: 12.2736
# Conditional Model - Epoch [2/10], Step [300/938], Loss: 8.6993
# Conditional Model - Epoch [2/10], Step [400/938], Loss: 8.2912
# Conditional Model - Epoch [2/10], Step [500/938], Loss: 8.2612
# Conditional Model - Epoch [2/10], Step [600/938], Loss: 8.8847
# Conditional Model - Epoch [2/10], Step [700/938], Loss: 8.9036
# Conditional Model - Epoch [2/10], Step [800/938], Loss: 7.0737
# Conditional Model - Epoch [2/10], Step [900/938], Loss: 10.5905
# Conditional Model - Epoch [3/10], Step [100/938], Loss: 8.1818
# Conditional Model - Epoch [3/10], Step [200/938], Loss: 6.9560
# Conditional Model - Epoch [3/10], Step [300/938], Loss: 6.9742
# Conditional Model - Epoch [3/10], Step [400/938], Loss: 8.9362
# Conditional Model - Epoch [3/10], Step [500/938], Loss: 8.6973
# Conditional Model - Epoch [3/10], Step [600/938], Loss: 10.4054
# Conditional Model - Epoch [3/10], Step [700/938], Loss: 7.4417
# Conditional Model - Epoch [3/10], Step [800/938], Loss: 8.0433
# Conditional Model - Epoch [3/10], Step [900/938], Loss: 8.8694
# Conditional Model - Epoch [4/10], Step [100/938], Loss: 6.6881
# Conditional Model - Epoch [4/10], Step [200/938], Loss: 6.7681
# Conditional Model - Epoch [4/10], Step [300/938], Loss: 7.1774
# Conditional Model - Epoch [4/10], Step [400/938], Loss: 6.1681
# Conditional Model - Epoch [4/10], Step [500/938], Loss: 9.1656
# Conditional Model - Epoch [4/10], Step [600/938], Loss: 7.5613
# Conditional Model - Epoch [4/10], Step [700/938], Loss: 5.7305
# Conditional Model - Epoch [4/10], Step [800/938], Loss: 6.1709
# Conditional Model - Epoch [4/10], Step [900/938], Loss: 5.9766
# Conditional Model - Epoch [5/10], Step [100/938], Loss: 7.9405
# Conditional Model - Epoch [5/10], Step [200/938], Loss: 8.1440
# Conditional Model - Epoch [5/10], Step [300/938], Loss: 6.9361
# Conditional Model - Epoch [5/10], Step [400/938], Loss: 11.2739
# Conditional Model - Epoch [5/10], Step [500/938], Loss: 7.0283
# Conditional Model - Epoch [5/10], Step [600/938], Loss: 6.7516
# Conditional Model - Epoch [5/10], Step [700/938], Loss: 6.2480
# Conditional Model - Epoch [5/10], Step [800/938], Loss: 7.0209
# Conditional Model - Epoch [5/10], Step [900/938], Loss: 6.9562
# Conditional Model - Epoch [6/10], Step [100/938], Loss: 5.9114
# Conditional Model - Epoch [6/10], Step [200/938], Loss: 6.0902
# Conditional Model - Epoch [6/10], Step [300/938], Loss: 7.3346
# Conditional Model - Epoch [6/10], Step [400/938], Loss: 6.7155
# Conditional Model - Epoch [6/10], Step [500/938], Loss: 7.2313
# Conditional Model - Epoch [6/10], Step [600/938], Loss: 5.7265
# Conditional Model - Epoch [6/10], Step [700/938], Loss: 7.2291
# Conditional Model - Epoch [6/10], Step [800/938], Loss: 6.5100
# Conditional Model - Epoch [6/10], Step [900/938], Loss: 7.1817
# Conditional Model - Epoch [7/10], Step [100/938], Loss: 5.9106
# Conditional Model - Epoch [7/10], Step [200/938], Loss: 6.3021
# Conditional Model - Epoch [7/10], Step [300/938], Loss: 7.3152
# Conditional Model - Epoch [7/10], Step [400/938], Loss: 7.0140
# Conditional Model - Epoch [7/10], Step [500/938], Loss: 6.1877
# Conditional Model - Epoch [7/10], Step [600/938], Loss: 5.9673
# Conditional Model - Epoch [7/10], Step [700/938], Loss: 7.0025
# Conditional Model - Epoch [7/10], Step [800/938], Loss: 6.6691
# Conditional Model - Epoch [7/10], Step [900/938], Loss: 5.8733
# Conditional Model - Epoch [8/10], Step [100/938], Loss: 6.0934
# Conditional Model - Epoch [8/10], Step [200/938], Loss: 6.1589
# Conditional Model - Epoch [8/10], Step [300/938], Loss: 6.3534
# Conditional Model - Epoch [8/10], Step [400/938], Loss: 6.2534
# Conditional Model - Epoch [8/10], Step [500/938], Loss: 7.2167
# Conditional Model - Epoch [8/10], Step [600/938], Loss: 6.4143
# Conditional Model - Epoch [8/10], Step [700/938], Loss: 7.7891
# Conditional Model - Epoch [8/10], Step [800/938], Loss: 7.9574
# Conditional Model - Epoch [8/10], Step [900/938], Loss: 5.7479
# Conditional Model - Epoch [9/10], Step [100/938], Loss: 5.7253
# Conditional Model - Epoch [9/10], Step [200/938], Loss: 7.1967
# Conditional Model - Epoch [9/10], Step [300/938], Loss: 6.1574
# Conditional Model - Epoch [9/10], Step [400/938], Loss: 6.3853
# Conditional Model - Epoch [9/10], Step [500/938], Loss: 7.8834
# Conditional Model - Epoch [9/10], Step [600/938], Loss: 10.6129
# Conditional Model - Epoch [9/10], Step [700/938], Loss: 7.2548
# Conditional Model - Epoch [9/10], Step [800/938], Loss: 8.8315
# Conditional Model - Epoch [9/10], Step [900/938], Loss: 6.2265
# Conditional Model - Epoch [10/10], Step [100/938], Loss: 6.9745
# Conditional Model - Epoch [10/10], Step [200/938], Loss: 6.9183
# Conditional Model - Epoch [10/10], Step [300/938], Loss: 7.3522
# Conditional Model - Epoch [10/10], Step [400/938], Loss: 6.9090
# Conditional Model - Epoch [10/10], Step [500/938], Loss: 7.6022
# Conditional Model - Epoch [10/10], Step [600/938], Loss: 7.7369
# Conditional Model - Epoch [10/10], Step [700/938], Loss: 6.0319
# Conditional Model - Epoch [10/10], Step [800/938], Loss: 6.9237
# Conditional Model - Epoch [10/10], Step [900/938], Loss: 6.1901

# %%
# Evaluate the conditional diffusion model using negative log-likelihood and perceptual metrics
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transforms.ToTensor())
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)

nll_loss_total = 0
perceptual_loss_total = 0
with torch.no_grad():
    for images, labels in test_loader:
        # Flatten the images
        images = images.view(images.size(0), -1)

        # One-hot encode the labels
        labels_onehot = torch.zeros(images.size(0), 10)
        labels_onehot.scatter_(1, labels.view(-1, 1), 1)

        # Forward pass
        outputs = conditional_model(images, labels_onehot)

        # Compute the negative log-likelihood loss
        nll_loss_total += nll_loss(outputs, images).item()

        # Compute the perceptual loss
        perceptual_loss_total += perceptual_loss(outputs, images).item()

        # Plot the original and reconstructed images
        fig, axs = plt.subplots(1, 2)
        axs[0].imshow(images[0].view(28, 28), cmap='gray')
        axs[0].set_title('Original')
        axs[1].imshow(outputs[0].view(28, 28), cmap='gray')
        axs[1].set_title('Reconstructed')
        plt.show()

nll_loss_avg = nll_loss_total / len(test_loader)
perceptual_loss_avg = perceptual_loss_total / len(test_loader)

print('Conditional Model - Negative Log-Likelihood Loss: {:.4f}'.format(nll_loss_avg))
print('Conditional Model - Perceptual Loss: {:.4f}'.format(perceptual_loss_avg))
# Out:
# Conditional Model - Negative Log-Likelihood Loss: 6.2817
# Conditional Model - Perceptual Loss: 0.0576
